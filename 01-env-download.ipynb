# %%
pip install geemap==0.32.0
# Out:
# Requirement already satisfied: geemap==0.32.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (0.32.0)
# Requirement already satisfied: bqplot in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (0.12.43)
# Requirement already satisfied: colour in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (0.1.5)
# Requirement already satisfied: earthengine-api>=0.1.347 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (1.1.1)
# Requirement already satisfied: eerepr>=0.0.4 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (0.0.4)
# Requirement already satisfied: folium>=0.13.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (0.17.0)
# Requirement already satisfied: geocoder in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (1.38.1)
# Requirement already satisfied: ipyevents in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.17.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (0.19.2)
# Requirement already satisfied: ipytree in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (0.2.2)
# Requirement already satisfied: matplotlib in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (3.7.5)
# Requirement already satisfied: numpy in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (1.24.4)
# Requirement already satisfied: pandas in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (2.0.3)
# Requirement already satisfied: plotly in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (5.24.1)
# Requirement already satisfied: pyperclip in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (1.9.0)
# Requirement already satisfied: pyshp>=2.1.3 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (2.3.1)
# Requirement already satisfied: python-box in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (7.2.0)
# Requirement already satisfied: scooby in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geemap==0.32.0) (0.10.0)
# Requirement already satisfied: google-cloud-storage in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from earthengine-api>=0.1.347->geemap==0.32.0) (2.18.2)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from earthengine-api>=0.1.347->geemap==0.32.0) (2.147.0)
# Requirement already satisfied: google-auth>=1.4.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from earthengine-api>=0.1.347->geemap==0.32.0) (2.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from earthengine-api>=0.1.347->geemap==0.32.0) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from earthengine-api>=0.1.347->geemap==0.32.0) (0.22.0)
# Requirement already satisfied: requests in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from earthengine-api>=0.1.347->geemap==0.32.0) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from folium>=0.13.0->geemap==0.32.0) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from folium>=0.13.0->geemap==0.32.0) (3.1.4)
# Requirement already satisfied: xyzservices in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from folium>=0.13.0->geemap==0.32.0) (2024.9.0)
# Requirement already satisfied: ipywidgets in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipyfilechooser>=0.6.0->geemap==0.32.0) (8.1.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipyleaflet>=0.17.0->geemap==0.32.0) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipyleaflet>=0.17.0->geemap==0.32.0) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from bqplot->geemap==0.32.0) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from pandas->geemap==0.32.0) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from pandas->geemap==0.32.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from pandas->geemap==0.32.0) (2024.2)
# Requirement already satisfied: click in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geocoder->geemap==0.32.0) (8.1.7)
# Requirement already satisfied: future in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geocoder->geemap==0.32.0) (1.0.0)
# Requirement already satisfied: ratelim in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geocoder->geemap==0.32.0) (0.1.6)
# Requirement already satisfied: six in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from geocoder->geemap==0.32.0) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib->geemap==0.32.0) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib->geemap==0.32.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib->geemap==0.32.0) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib->geemap==0.32.0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib->geemap==0.32.0) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib->geemap==0.32.0) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib->geemap==0.32.0) (3.1.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib->geemap==0.32.0) (6.4.5)
# Requirement already satisfied: tenacity>=6.2.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from plotly->geemap==0.32.0) (9.0.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap==0.32.0) (2.20.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap==0.32.0) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap==0.32.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap==0.32.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap==0.32.0) (4.9)
# Requirement already satisfied: zipp>=3.1.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->geemap==0.32.0) (3.20.2)
# Requirement already satisfied: comm>=0.1.3 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (8.12.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from jinja2>=2.9->folium>=0.13.0->geemap==0.32.0) (2.1.5)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap==0.32.0) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap==0.32.0) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap==0.32.0) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from requests->earthengine-api>=0.1.347->geemap==0.32.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from requests->earthengine-api>=0.1.347->geemap==0.32.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from requests->earthengine-api>=0.1.347->geemap==0.32.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from requests->earthengine-api>=0.1.347->geemap==0.32.0) (2024.8.30)
# Requirement already satisfied: decorator in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ratelim->geocoder->geemap==0.32.0) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap==0.32.0) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap==0.32.0) (5.28.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap==0.32.0) (1.24.0)
# Requirement already satisfied: backcall in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.1.7)
# Requirement already satisfied: pickleshare in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (2.18.0)
# Requirement already satisfied: stack-data in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.6.2)
# Requirement already satisfied: typing-extensions in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (4.9.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.347->geemap==0.32.0) (0.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.7.0)
# Requirement already satisfied: wcwidth in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (2.4.1)
# Requirement already satisfied: pure-eval in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.32.0) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tk==0.1.0
# Out:
# Requirement already satisfied: tk==0.1.0 in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pycrs
# Out:
# Requirement already satisfied: pycrs in /home/dyclab/miniconda3/envs/myenv/lib/python3.8/site-packages (1.0.2)

# %%
import os
import ee
import geemap
from pathlib import Path
from datetime import datetime, timedelta , date
import time
import pandas as pd
import csv
import glob
import folium
from IPython.display import display, clear_output
import shutil
import shapefile
import ipywidgets as widgets
from tkinter import Tk, filedialog
import traitlets
from ipyfilechooser import FileChooser
import math
import logging

# %%
class SelectFilesButton(widgets.Button):
    """A file widget that leverages tkinter.filedialog."""

    def __init__(self):
        super(SelectFilesButton, self).__init__()
        # Add the selected_files trait
        self.add_traits(files=traitlets.traitlets.List())
        # Create the button.
        self.description = "Select Files"
        self.icon = "square-o"
        self.style.button_color = "orange"
        # Set on click behavior.
        self.on_click(self.select_files)

    @staticmethod
    def select_files(b):
        """Generate instance of tkinter.filedialog.

        Parameters
        ----------
        b : obj:
            An instance of ipywidgets.widgets.Button 
        """
        # Create Tk root
        root = Tk()
        # Hide the main window
        root.withdraw()
        # Raise the root to the top of all windows.
        root.call('wm', 'attributes', '.', '-topmost', True)
        # List of selected fileswill be set to b.value
        b.files = filedialog.askopenfilename(multiple=True,filetypes=[('shp','.shp')])

        b.description = "Files Selected"
        b.icon = "check-square-o"
        b.style.button_color = "lightgreen"


def _last_day_of_month(any_day):
    next_month = any_day.replace(day=28) + timedelta(days=4)  # this will never fail
    return next_month - timedelta(days=next_month.day)


def monthlist(begin,end):
    # begin = datetime.strptime(begin, "%Y-%m-%d")
    # end = datetime.strptime(end, "%Y-%m-%d")

    result = []
    while True:
        if begin.month == 12:
            next_month = begin.replace(year=begin.year+1,month=1, day=1)
        else:
            next_month = begin.replace(month=begin.month+1, day=1)
        if next_month > end:
            break
        result.append ([begin.strftime("%Y-%m-%d"),_last_day_of_month(begin).strftime("%Y-%m-%d")])
        begin = next_month
    result.append ([begin.strftime("%Y-%m-%d"),end.strftime("%Y-%m-%d")])
    return result


def monthlist(begin,end):
    # begin = datetime.strptime(begin, "%Y-%m-%d")
    # end = datetime.strptime(end, "%Y-%m-%d")

    result = []
    while True:
        if begin.month == 12:
            next_month = begin.replace(year=begin.year+1,month=1, day=1)
        else:
            next_month = begin.replace(month=begin.month+1, day=1)
        if next_month > end:
            break
        result.append ([begin.strftime("%Y-%m-%d"),_last_day_of_month(begin).strftime("%Y-%m-%d")])
        begin = next_month
    result.append ([begin.strftime("%Y-%m-%d"),end.strftime("%Y-%m-%d")])
    return result


def date_format_concersion(date, output_format='%Y/%m/%d'):

    # Fool-proof: check if the input date is None
    if date is None:
        return None

    try: 
        parsed_date = datetime.strptime(date, output_format)
        
    except ValueError as e:

        try:
            # Try to parse the input date
            parsed_date = datetime.strptime(date, '%Y%m%d')
        except ValueError as e:
        
            try:
                parsed_date = datetime.strptime(date, '%Y_%m_%d')
            except ValueError as e:

                try:
                    parsed_date = datetime.strptime(date, '%Y-%m-%d')
                except ValueError as e:

                    return logging.error(f'Unparsable date format {e}')

    output_date = parsed_date.strftime(output_format)

    return output_date

def getRH(image):
    
    RH = image.expression(
      '100 * (exp((17.625 * Td)/(243.04 + Td))/exp((17.625*T)/(243.04 + T)))',{
      'Td' : image.select('dewpoint_temperature_2m').add(-273.15),
      'T' : image.select('temperature_2m').add(-273.15)}).rename('Relative_Humidity')
    
    return image.addBands(RH)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# After executing this line of code for the first use, you can get the authentication number linked to Google.
Map = geemap.Map()
# Authenticate the Google earth engine with google account
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# give the star date and end date

star = widgets.DatePicker(
    description='Pick a Star Date',
    disabled=False
)
end = widgets.DatePicker(
    description='Pick a End Date',
    disabled=False
)

widgets.HBox([star, end])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# HBox(children=(DatePicker(value=None, description='Pick a Star Date', step=1), DatePicker(value=None, descript…

# %%
import os

# Replace 'your_directory_path' with the actual path
directory_J = 'D:/shp/shp_separate'

# 建立一個空的 list 用來存放結果
paths_list = []

# 列出該目錄下的所有檔案
files_J = os.listdir(directory_J)

files_J
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['id_10801to12600',
#  'id_12601to14400',
#  'id_14401to16200',
#  'id_16201to17100',
#  'id_17101to18000',
#  'id_18001to18900',
#  'id_1801to3600',
#  'id_18901to19800',
#  'id_19801to20700',
#  'id_1to1800',
#  'id_20701to21600',
#  'id_21601to22126',
#  'id_3601to5400',
#  'id_5401to7200',
#  'id_7201to8100',
#  'id_8101to9000',
#  'id_9001to10800']

# %%
files_J [len(files_J)-1]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 'id_9001to10800'

# %%
len(time_list)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 3

# %%
len(env_var_list)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 59

# %%
len(statics_OwO)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 7

# %%
#J loop, but time need to select

##list file
import os

# Replace 'your_directory_path' with the actual path
directory_J = 'D:/shp/shp_separate'

# 建立一個空的 list 用來存放結果
paths_list = []

# 列出該目錄下的所有檔案
files_J = os.listdir(directory_J)

# 遍歷檔案並生成完整路徑，將其加入 paths_list 中
for i in files_J:
    whole_path_J = directory_J + '/' + i + '/' + i + '.shp'
    #print(whole_path_J)
    
    # 將每個完整路徑加入 list 中
    paths_list.append(whole_path_J)

#shpfile_OwO = paths_list[0:3]
#--------------------------------------------------------------
## 環境變數的 list
# 原始的清單
original_list = [
    'dewpoint_temperature_2m', 
    'temperature_2m',
    'temperature_2m_min',
    'temperature_2m_max',
    'skin_temperature', 
    'soil_temperature_level_1', 
    'soil_temperature_level_2', 
    'soil_temperature_level_3', 
    'soil_temperature_level_4',
    'lake_bottom_temperature',
    'lake_ice_depth',
    'lake_ice_temperature',
    'lake_mix_layer_depth',
    'lake_mix_layer_temperature', 
    'lake_shape_factor', 
    'lake_total_layer_temperature',
    'snow_albedo',
    'snow_cover',
    'snow_density',
    'snow_depth',
    'snow_depth_water_equivalent',
    'snowfall_sum',
    'snowmelt_sum',
    'temperature_of_snow_layer',
    'skin_reservoir_content',
    'volumetric_soil_water_layer_1',
    'volumetric_soil_water_layer_2',
    'volumetric_soil_water_layer_3',
    'volumetric_soil_water_layer_4',
    'forecast_albedo',
    'surface_latent_heat_flux_sum',
    'surface_net_solar_radiation_sum',
    'surface_net_thermal_radiation_sum',
    'surface_sensible_heat_flux_sum',
    'surface_solar_radiation_downwards_sum',
    'surface_thermal_radiation_downwards_sum',
    'evaporation_from_bare_soil_sum',
    'evaporation_from_open_water_surfaces_excluding_oceans_sum',
    'evaporation_from_the_top_of_canopy_sum',
    'evaporation_from_vegetation_transpiration_sum',
    'potential_evaporation_sum',
    'potential_evaporation_min',
    'potential_evaporation_max',
    'runoff_sum',
    'snow_evaporation_sum',
    'sub_surface_runoff_sum',
    'surface_runoff_sum',
    'total_evaporation_sum',
    'total_evaporation_min',
    'total_evaporation_max',
    'u_component_of_wind_10m',
    'v_component_of_wind_10m',
    'surface_pressure',
    'total_precipitation_sum',
    'total_precipitation_min',
    'total_precipitation_max',
    'leaf_area_index_high_vegetation',
    'leaf_area_index_low_vegetation',
    'Relative_Humidity'
]

# 將每個元素轉換為單一元素的元組，並存入新的清單
env_var_list = [(item,) for item in original_list]
#band_name = ('temperature_2m',)

#--------------------------------------------------------------
# statics list
statics_OwO =['MEAN','MAXIMUM', 'MINIMUM', 'MEDIAN', 'STD', 'VARIANCE', 'SUM']
#statics = 'MEAN'


#-----------------------------------------------
file_name = 'Id'

#---------------------------------------------------------

# create folder
folder_name = 'data_all'

# create folder name : data_all
if os.path.isdir(folder_name) == True:
    shutil.rmtree(folder_name, ignore_errors=True)
    os.makedirs(folder_name)
else:
    os.makedirs(folder_name)

#-------------------------------------------------------------

for file_id_OwO in files_J[9:10]:
    shpfile_OwO = directory_J + '/' + file_id_OwO + '/' + file_id_OwO + '.shp'
    for band_name in env_var_list[0:len(env_var_list)]:
        for statics in statics_OwO[0:len(statics_OwO)]:
            time_list = monthlist(star.value, end.value)
            states = geemap.shp_to_ee(shpfile_OwO)
            for i in range(0, len(time_list)):
                    Era5 = ee.ImageCollection('ECMWF/ERA5_LAND/DAILY_AGGR') \
                    .filter(ee.Filter.date(datetime.strptime(time_list[i][0], "%Y-%m-%d"), datetime.strptime(time_list[i][1], "%Y-%m-%d")+timedelta(days=1))) \
                    .map(getRH) \
                    .map(lambda image: image.select(list(band_name))) \
                    .map(lambda image: image.clip(states)) \
                    .map(lambda image: image.reproject(crs='EPSG:4326'))
                    
                    #改動
                    if Era5.size().getInfo() > 0:
                        Era5 = Era5.toBands()
                    else:
                        print("No images found for the given date range.")
                        continue
                    #---------------------------
                    out_dir = os.path.expanduser(folder_name)
                    out_dem_stats = os.path.join(
                        out_dir, 'Era5_{}_{}.csv'.format(statics, time_list[i]))
            
                    if not os.path.exists(out_dir):
                        os.makedirs(out_dir)
            
                    geemap.zonal_statistics(
                        Era5, states, out_dem_stats, statistics_type=statics, scale=1000)
            
                    data_temp = pd.read_csv(out_dem_stats)
            
                    data = []
            
                    if (len(band_name)) == 1 & (time_list[i][0] == time_list[i][1]):
            
                        df = data_temp
                        df[file_name] = data_temp.loc[:,[file_name]]
                        df['Date'] = date_format_concersion(
                            time_list[i][0], output_format='%Y/%m/%d')
                        df['Doy'] = datetime.strptime(
                            time_list[i][0], '%Y-%m-%d').strftime('%j')
                        select_columns = ['Date', 'Doy'] + [item.lower() for item in [statics]] + [file_name]
                        df = df[select_columns]
                        new_columns = ['Date', 'Doy'] +                 band_name + [file_name]
                        df.columns = new_columns
            
                        data.append(df)
            
                    else:
                        column_name_list = data_temp.columns.tolist()
                        c = []
                        d = []
                        for k in zip(column_name_list[:]):
                            c.append(k[0][0:8])
                            d.append(k[0])
            
                        data = []
                        for j in range(0, len(column_name_list), len(band_name)):
            
                            # Check date format and extract data Check date format and extract data
                            if all(m.isdigit() for m in c[j:j+len(band_name)]) == True:
            
                                # Extract data
                                df = data_temp.loc[:, d[j:j+len(band_name)]]
                                df[file_name] = data_temp.loc[:, [file_name]]
            
                                # Create new date and DOY columns
                                df.insert(0, 'Date', '')
                                df['Date'] = date_format_concersion(
                                    time_list[i][0], output_format='%Y/%m/%d')
            
                                df.insert(1, 'Doy', '')
                                df['Doy'] = datetime.strptime(
                                    time_list[i][0], '%Y-%m-%d').strftime('%j')
            
                                # Rename columns
                                colnames = ['Date', 'Doy']
                                colnames.extend(list(band_name))
                                colnames.append(file_name)
                                df.columns = [colnames]
            
                                data.append(df)
                            else:
                                continue
            
                    appended_data = pd.concat(data, axis=0, ignore_index=True)
            
                    # Output the file with date and doy back
                    appended_data.to_csv(out_dem_stats, index=False)
            
            
            def _rename_columns(df, column_name, suffix):
                if column_name in df.columns:
                    df.rename(columns={column_name: f"{column_name}_{suffix}"}, inplace=True)
            
            def cbind_era5(statics):
            
                all_files = glob.glob(os.path.join(folder_name , "Era5_{}*.csv".format(statics)))
                
                df_from_each_file = (pd.read_csv(f, sep = ",") for f in all_files)
                df_merged = pd.concat(df_from_each_file, ignore_index = True)
            
                for column_name in df_merged.columns:
                    if column_name in band_name:
                        _rename_columns(df_merged, column_name, str(statics))
            
                band_name_str = ', '.join(band_name)
                
                df_merged.to_csv('D:/result/result' + 
                                 '/' +
                                 file_id_OwO + 
                                 '/' +
                                 band_name_str +
                                 '_' +
                                 statics +
                                 '_' +
                                 str(star.value) +
                                 '_' +
                                 'to' +
                                 '_' +
                                 str(end.value) +
                                 '.csv', index=False)
            
            
            cbind_era5(statics)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/4089220452d0f77d588a8b9874741667-74185db9f79d6eeba2bc341f0c992087:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-01-01', '2015-01-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/852ff1ef1cec134c41508489ca725e79-0293df779a0346de5dfbdfefa081a2cd:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-02-01', '2015-02-28'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/c8559bfb8da460e41c23991a179c7328-c62d61e51f86d3a962f11d92f9d7ac15:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-03-01', '2015-03-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/48ba3691f9f898bc6e967ba0d18c2c82-f70122e2dc462c4abd5c0e454a02513f:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-04-01', '2015-04-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/7e7bf0731db37457352ec1af459a5d50-21ba8ca4b1a8bc4a7686872092066ebd:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-05-01', '2015-05-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/e1ffed0f04595ab40a13fb2cda141830-164a9c9c96079614e87dc4ad692155cc:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-06-01', '2015-06-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/4c5e9dbe9b2905a5f95a5be38fbf361e-509d3cf7e9a01b4486f4a815cdd402d6:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-07-01', '2015-07-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/c073dbd804f5ef21b91601705ad2f296-3ab455ecc991a787897757bf80410cee:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-08-01', '2015-08-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/88169ffbd53b96669024e5393cd3eedc-ce6b56c9d8bb067d8f6f17475830467c:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-09-01', '2015-09-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/e2e79df96429048cc2a89ee61a5a8a69-b80b61d721535f9379b46b5a2d3cd183:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-10-01', '2015-10-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/853d226bce038e053f0c59df614deb82-18feabba95a5e36fac0965db4b447a3f:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-11-01', '2015-11-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/2c6d08ea745ec9952e835698dce16355-9ea685646c558c60d1c3698b378f5b4f:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2015-12-01', '2015-12-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/4807ca858117c96fcc2888007e764724-77d14323bde79d16c97156e4fb9ec725:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2016-01-01', '2016-01-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/81fc78a92d520cc65cacb12b563a54e2-edec76cc39ccc0e4f16bfa6ad57f3661:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2016-02-01', '2016-02-29'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables/91ae4bab6bda77879bd1df32eba5ca29-34bfb95fe92f0cd52c32a260b7831b79:getFeatures
# Please wait ...
# Data downloaded to C:\Users\user\data_all\Era5_MEAN_['2016-03-01', '2016-03-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/54070352135/tables