# %%
import os
import ee
import geemap
from datetime import datetime, timedelta
import pandas as pd
import time
import shutil
from ipywidgets import widgets
from tkinter import Tk, filedialog

# %%
class SelectFilesButton(widgets.Button):
    """A file widget that leverages tkinter.filedialog."""
    def __init__(self):
        super(SelectFilesButton, self).__init__()
        self.add_traits(files=widgets.traitlets.List())
        self.description = "Select Files"
        self.icon = "square-o"
        self.style.button_color = "orange"
        self.on_click(self.select_files)

    @staticmethod
    def select_files(b):
        root = Tk()
        root.withdraw()
        root.call('wm', 'attributes', '.', '-topmost', True)
        b.files = filedialog.askopenfilename(multiple=True, filetypes=[('shp', '.shp')])
        b.description = "Files Selected"
        b.icon = "check-square-o"
        b.style.button_color = "lightgreen"

def _last_day_of_month(any_day):
    next_month = any_day.replace(day=28) + timedelta(days=4)  
    return next_month - timedelta(days=next_month.day)

def monthlist(begin, end):
    result = []
    while True:
        if begin.month == 12:
            next_month = begin.replace(year=begin.year + 1, month=1, day=1)
        else:
            next_month = begin.replace(month=begin.month + 1, day=1)
        if next_month > end:
            break
        result.append([begin.strftime("%Y-%m-%d"), _last_day_of_month(begin).strftime("%Y-%m-%d")])
        begin = next_month
    result.append([begin.strftime("%Y-%m-%d"), end.strftime("%Y-%m-%d")])
    return result

def date_format_concersion(date, output_format='%Y/%m/%d'):
    if date is None:
        return None
    try:
        parsed_date = datetime.strptime(date, output_format)
    except ValueError:
        try:
            parsed_date = datetime.strptime(date, '%Y%m%d')
        except ValueError:
            try:
                parsed_date = datetime.strptime(date, '%Y_%m_%d')
            except ValueError:
                try:
                    parsed_date = datetime.strptime(date, '%Y-%m-%d')
                except ValueError as e:
                    return logging.error(f'Unparsable date format {e}')
    return parsed_date.strftime(output_format)

# Function to get land cover from Dynamic World V1
def get_dynamic_world_landcover(image):
    land_cover = image.select([
        'water', 'trees', 'grass', 'flooded_vegetation',
        'crops', 'shrub_and_scrub', 'built', 'bare', 'snow_and_ice'
    ])
    return image.addBands(land_cover)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#J
ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=0tUD64RwiWcGbHESat49OJDVem3c--Y4_P_i7PKCvdo&tc=27JkoCXR6zGamLDCCLAWGdx1VePdnWW-YRQywpwNpYQ&cc=1q5PVCgspvdNaFWGDfgTRiKBQWfTefiY_CSGg8YSz4Y>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=0tUD64RwiWcGbHESat49OJDVem3c--Y4_P_i7PKCvdo&tc=27JkoCXR6zGamLDCCLAWGdx1VePdnWW-YRQywpwNpYQ&cc=1q5PVCgspvdNaFWGDfgTRiKBQWfTefiY_CSGg8YSz4Y</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AVG7fiS9x17uwpeiXt6lzO-8XeNEJUKAzTKhH0Pgf1TjBGEwhG3eULNSGNI
# Successfully saved authorization token.

# %%
# After executing this line of code for the first use, you can get the authentication number linked to Google.
Map = geemap.Map()
# Authenticate the Google earth engine with google account
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Create date pickers for the user
star = widgets.DatePicker(description='Pick a Start Date', disabled=False)
end = widgets.DatePicker(description='Pick an End Date', disabled=False)
widgets.HBox([star, end])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# HBox(children=(DatePicker(value=None, description='Pick a Start Date', step=1), DatePicker(value=None, descrip…

# %%
#J try to use era5 method 20241030
# success

##list file
import os
import glob

# Replace 'your_directory_path' with the actual path
#directory_J = '/media/dyclab/新增磁碟區/Jeffery/data/shp/EU_100km_fishnet_simple_by_distance/EU_100km_fishnet_simple_by_distance.shp'
directory_J = "D:/EU_100km_fishnet_simple_by_distance/EU_100km_fishnet_simple_by_distance/EU_100km_fishnet_simple_by_distance.shp"

## 環境變數的 list
# 原始的清單
original_list = [
    #"water",
    #"trees",
    #"grass",
    #"flooded_vegetation",
    #"crops",
    "shrub_and_scrub",
    "built",
    "bare",
    "snow_and_ice"
]



# 將每個元素轉換為單一元素的元組，並存入新的清單
env_var_list = [(item,) for item in original_list]
#band_name = ('temperature_2m',)

#--------------------------------------------------------------
# statics list
statics_OwO =['MEAN','MAXIMUM', 'MINIMUM', 'MEDIAN', 'STD', 'VARIANCE', 'SUM']
#statics = 'MEAN'


#-----------------------------------------------
file_name = 'Id'

#---------------------------------------------------------

# create folder
folder_name = 'dynamic_world_data'

# create folder name : data_all
if os.path.isdir(folder_name) == True:
    shutil.rmtree(folder_name, ignore_errors=True)
    os.makedirs(folder_name)
else:
    os.makedirs(folder_name)

#-------------------------------------------------------------

import time

#shpfile_OwO = '/media/dyclab/新增磁碟區/Jeffery/data/shp/EU_100km_fishnet_simple_by_distance/EU_100km_fishnet_simple_by_distance.shp'
shpfile_OwO = "D:/EU_100km_fishnet_simple_by_distance/EU_100km_fishnet_simple_by_distance/EU_100km_fishnet_simple_by_distance.shp"

for band_name in env_var_list:
    for statics in statics_OwO[0:1]:
        start_time = time.time()
        time_list = monthlist(star.value, end.value)
        states = geemap.shp_to_ee(shpfile_OwO)
        for i in range(0, len(time_list)):
                dynamic_world = ee.ImageCollection('GOOGLE/DYNAMICWORLD/V1') \
                .filter(ee.Filter.date(datetime.strptime(time_list[i][0], "%Y-%m-%d"), datetime.strptime(time_list[i][1], "%Y-%m-%d")+timedelta(days=1))) \
                .map(lambda image: image.select(list(band_name))) \
                .map(lambda image: image.clip(states)) \
                .map(lambda image: image.reproject(crs='EPSG:4326'))

                #改動
                if dynamic_world.size().getInfo() > 0:
                    dynamic_world_monthly_avg = dynamic_world.mean()
                else:
                    print("No images found for the given date range.")
                    continue
                #---------------------------
                out_dir = os.path.expanduser(folder_name)
                out_dem_stats = os.path.join(
                    out_dir, 'dynamic_world_{}_{}.csv'.format(statics, time_list[i]))

                if not os.path.exists(out_dir):
                    os.makedirs(out_dir)

                geemap.zonal_statistics(
                dynamic_world_monthly_avg, states, out_dem_stats, statistics_type=statics, scale=1000)
                
                
                data_temp = pd.read_csv(out_dem_stats)

                data = []
                
                # 初始化 df 為 data_temp 的副本
                df = data_temp.copy()


                mean_OwO = 'mean'
                
                if mean_OwO in data_temp.columns:
                    # Extract data
                    df[file_name] = data_temp.loc[:, [file_name]]
                    df[mean_OwO] = data_temp.loc[:, [mean_OwO]]

                    df.insert(0, 'Date', '')
                    df['Date'] = date_format_concersion(
                        time_list[i][0], output_format='%Y/%m/%d')

                    df.insert(1, 'Doy', '')
                    df['Doy'] = datetime.strptime(
                        time_list[i][0], '%Y-%m-%d').strftime('%j')

                    # Rename columns

                    band_name_OwO = ''.join(band_name)
                    df = df.rename(columns={'mean': band_name_OwO})

                    data.append(df)
                
                # 如果都是空直, 填入na
                else:
                    import numpy as np
                    df[file_name] = data_temp.loc[:, [file_name]]
                    
                    df.insert(0, mean_OwO, np.nan)

                    df.insert(0, 'Date', '')
                    df['Date'] = date_format_concersion(
                        time_list[i][0], output_format='%Y/%m/%d')

                    df.insert(1, 'Doy', '')
                    df['Doy'] = datetime.strptime(
                        time_list[i][0], '%Y-%m-%d').strftime('%j')

                    # Rename columns

                    band_name_OwO = ''.join(band_name)
                    df = df.rename(columns={'mean': band_name_OwO})

                    data.append(df)
                

                # 檢查 data 是否為空，再執行合併
                if data:
                    appended_data = pd.concat(data, axis=0, ignore_index=True)
                    # Output the file with date and doy back
                    appended_data.to_csv(out_dem_stats, index=False)
                else:
                    print("No data to concatenate")
                

                
        end_time = time.time()
        # 計算時間差
        elapsed_time = end_time - start_time
        # 列印這次迴圈的執行時間
        print(f"迴圈執行時間: {elapsed_time:.4f} 秒")



        def _rename_columns(df, column_name, suffix):
            if column_name in df.columns:
                df.rename(columns={column_name: f"{column_name}_{suffix}"}, inplace=True)

        def cbind_dynamic_world(statics):

            all_files = glob.glob(os.path.join(folder_name , "dynamic_world_{}*.csv".format(statics)))

            df_from_each_file = (pd.read_csv(f, sep = ",") for f in all_files)
            df_merged = pd.concat(df_from_each_file, ignore_index = True)

            for column_name in df_merged.columns:
                if column_name in band_name:
                    _rename_columns(df_merged, column_name, str(statics))

            band_name_str = ', '.join(band_name)

            df_merged.to_csv('D:/EU_result/dynamic_world_result/' + 
                             band_name_str +
                             '_' +
                             statics +
                             '_' +
                             str(star.value) +
                             '_' +
                             'to' +
                             '_' +
                             str(end.value) +
                             '.csv', index=False)


        cbind_dynamic_world(statics)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/0b66e24c1b011e6256011839ebf10384-ad6554e1bef57f9004e023ed382216d6:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-10-17', '2015-10-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/9df59159962ff358a2154df32d558f29-010e691ae371748e3cae03ecc3eb48c8:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-11-01', '2015-11-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/faee2d6a49322f70c996e91f4d31e2ff-6c7df8b2af22236eaf5efc0c2eb27854:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-12-01', '2015-12-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/90a9c34ecfcc37631b5710f1a4dea5b0-8fdd0fcae8017ecaf5d556f89eca5453:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-01-01', '2016-01-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/f8e192e02252818c7090773edbb4c34e-6f0db04854e61b48549a34ba1f88a508:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-02-01', '2016-02-29'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/d11f25df9ce982be1a4090618139f34c-cf3c9aef962b5844b40f8259f6d1f9e6:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-03-01', '2016-03-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/6fd2a99e078025d915614b25cb6bcd21-6c3a38050293be47cefbb2f7609c10c8:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-04-01', '2016-04-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/641aead07ef956c340088e92e3e8a9c0-8df31886936e46f28501faebafb8d64f:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-05-01', '2016-05-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/c4ab04af24dbfc75b1b547a0b740f6e2-a27eed103825fa7651111dfd615c1864:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-06-01', '2016-06-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/0d60c9351c4b1f01eafd9d13bff8aa90-7cebeb60fca53a2dc57c61dc3bb4323d:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-07-01', '2016-07-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/81b2a6ae50243504ef285603fcaa23ae-6d1d6b0d0dc22b932feeb98feddeb14c:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-08-01', '2016-08-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/0c3a03f486fcf6692c2c2d6def70d9e2-5f835fe1475fdb0efde64528ccfd61af:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-09-01', '2016-09-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/697c32671e5bf62b1615b708c2263b10-b8ac685096be78221295ecab15053fa3:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-10-01', '2016-10-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/c1c2e8da820b07e8b7310155022bd5d2-f3a0e06b5d00554bb7dc4773a489659f:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-11-01', '2016-11-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/556ce500e7bd11afd19eea5dca5efca7-a6bde76477b9743dca0b9e270807e09a:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-12-01', '2016-12-31'].csv
# 迴圈執行時間: 2186.7229 秒
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/99b4cdeadb025c58734e2d93e631b159-fbc6b3908da732e47e1b9bb5f090c5cc:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-10-17', '2015-10-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/8cfa23d1f266b0681aebecc448dd94d8-1ec232e07c649e78258d8e13041b73fd:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-11-01', '2015-11-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/dcdbe6742ff7c03de1056b032787dbcf-4b959725ef10bd74fb3466435b1f6f41:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-12-01', '2015-12-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/168503ccc8337e915a5af63d0138f976-6e8758088f0ba0c2dee7237ab5824edb:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-01-01', '2016-01-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/9f00bbafda92015e2a68a285649e93d8-23cc304a475facc5a9ef26846022ca45:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-02-01', '2016-02-29'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/aa67f7d52b3f4c487e1f21ea076f814a-71b9d8f1619df42b19697e858aeb2552:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-03-01', '2016-03-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/ef141bbcddadb20be6954aaeef862f2d-b86f84f845cd6fa61999109cff7e1abf:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-04-01', '2016-04-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/a1787fd087736d3ec7825c6e148d2a73-6735bc941553abbdec0be9fe534dcea2:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-05-01', '2016-05-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/39e34211f0311a3f9ed31737e0257bbc-83862e67327588ce772cbaeddab18835:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-06-01', '2016-06-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/d479b2f0cead51dd5f04a247ae986541-bcfe8a7d8a017f86119aca23bb80ec55:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-07-01', '2016-07-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/b55d2b5182aa252398850ddcc0693b04-bf2a16b5b19db56f0bb6bb1fe337c7f0:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-08-01', '2016-08-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/cc06e5a61e31e54c9c1a18c90585185c-cf968a8560dc275b88b0933ff40bec6c:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-09-01', '2016-09-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/615008ba43957888240d49e205a137b8-5ff3a2e1d2881c08a2a1849d523dd223:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-10-01', '2016-10-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/4bc51a6dbab4fbed80ed8aa0f5836352-dbe4bb4fb41114b0201dc442f9e0ead0:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-11-01', '2016-11-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/21e1a81f6050308f3c74f9a668b1fd1b-ab1678b3f700d2b0cd6ef8e01d607dc7:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-12-01', '2016-12-31'].csv
# 迴圈執行時間: 2296.2681 秒
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/e8cca479f21f61531f7966a3fa8dd9c8-68c387b7f34cb88c015c579c4150d653:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-10-17', '2015-10-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/adb9b87f7edf5615f601fc04abfd9c94-c0d5bcafc6922c5e8cf5ca9891aa3bfa:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-11-01', '2015-11-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/64b43a91696bef16a3e7fe6d9bd8c8a2-9ba415e28a428b646e34f7caf957a473:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-12-01', '2015-12-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/c6c6cef2ddef9436dbd53ad7a7d6c518-8ffaaaedddb91d667b2f57884454a75e:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-01-01', '2016-01-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/d12f8f82d065c62506c374a57868c5d5-e8cb1a382a729144d3d5342f99f8d580:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-02-01', '2016-02-29'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/76b4a9b9bf7694c2deadbda79ce8b714-b64a183c325dfd3f366d4de80e4ca91d:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-03-01', '2016-03-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/230bf482b6d4108c2b0ed643669c0ed8-9256e7057188ddc5efd7df84cc9edf2e:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-04-01', '2016-04-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/ae1be012a8ae15661b44d95f8126c78c-f8ba3552d77684ea2ee76b91c7b68998:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-05-01', '2016-05-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/c6066577bae157bd6cdf18a1ef01eb87-012e6a4f4574a72fbf529b74ec6f0f00:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-06-01', '2016-06-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/cb24513ebe3741af12f50e9276e5ba53-d33a81f2de98642607e201ca948c27c6:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-07-01', '2016-07-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/0de1cfb2526feee127eacfcb0b312c11-34dde534378abf8da4ef0cfcedd936de:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-08-01', '2016-08-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/4a25914ec317f98a3173c3ab62a9c897-7e3d0908a08ad328f80a560fd44c82d5:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-09-01', '2016-09-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/336aeef0b403251e0814d613b1dfddc2-9c859354ec37270fd4a7580715bc3611:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-10-01', '2016-10-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/5126fffffef75c70d98a444a39053164-346267dac0db3f7b922cc1a52a48bf91:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-11-01', '2016-11-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/fe552386d2c285208419930f7739b22c-3fa5c04dec8da3386d076fba9caa8c5c:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-12-01', '2016-12-31'].csv
# 迴圈執行時間: 2107.6385 秒
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/e8e9f07a187d7b6d034b1eee586ea098-7611b54a4d782db1283bf324dfe7389a:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-10-17', '2015-10-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/793c99487f54a2e154ce2dfac77c8a3e-ea0e104b8578afcca73b04100e1c417e:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-11-01', '2015-11-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/c74976a0026af1ae80808d0cde3a8bdc-50f995ff5aaa69899990a6fd7dd21f23:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2015-12-01', '2015-12-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/233b2c237e47022224d99b7c6fd158ad-9603645e99396b3b4c5176a320621d8e:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-01-01', '2016-01-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/045625f7353c5fbc103842ce4cf274b2-e2f587cb3d9b4e19a73181a2bdc5e648:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-02-01', '2016-02-29'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/ec9db9e4b6f123cd9a4323d5f320e186-964c4f29e91275421d8dd9eca3c8624b:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-03-01', '2016-03-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/5babe060824a41d74a890840fb78c8de-7a6c0b904dbd80ca4f2e7c4d3b186648:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-04-01', '2016-04-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/280dacf40fab124b3de8da373923fbcf-c1086d34649af83754f3d525b3839ee1:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-05-01', '2016-05-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/72e3ebae331dd50194a2298ce114ab8d-af63d81648266ead89ee0cc252d56783:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-06-01', '2016-06-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/445117c25f0d5b65939c64b232151ee0-9e576f1b3d21b5e3499a1525dff63fcb:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-07-01', '2016-07-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/8fb7c9451452211f0a322839fb6021c9-24f0afd746492e577fc1c422de3d654a:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-08-01', '2016-08-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/e93eff924c8804b0222e51bf6942d7ff-e7a374896ac8efda23cbc118ed84d856:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-09-01', '2016-09-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/1556ee49353d93ce0adea77f59eca66c-dc914cdb47d38f5433ab388a9e6aa9bc:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-10-01', '2016-10-31'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/89d4ff0a7d0dc88536ec59bfa2ce1d4f-52d8ae82adff8f67cfb10a37d00e0c77:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-11-01', '2016-11-30'].csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/745009416911/tables/3cbea53b39c99af08423415d0c54f8b2-05dc9968bb72bf6fe32252522db04fab:getFeatures
# Please wait ...
# Data downloaded to C:\Users\吳宏達\dynamic_world_data\dynamic_world_MEAN_['2016-12-01', '2016-12-31'].csv
# 迴圈執行時間: 2287.0395 秒
